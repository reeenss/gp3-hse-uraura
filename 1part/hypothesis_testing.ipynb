# %% [markdown]
# Ключевая метрика: конверсия регистрации
#
# В качестве основной метрики эксперимента выбрана конверсия в регистрацию. Это метрика, которая непосредственно соответствует целям тестируемых изменений, так как направлена на увеличение числа зарегистрированных пользователей и отражает первый ключевой шаг продуктовой воронки.

# %% [markdown]
# # Гипотезы A/A control

# %% [markdown]
# №1
#
# **Нулевая гипотеза:** Подгруппы контрольной группы имеют одинаковую конверсию
#
# **Альтернативная:** Подгруппы контрольной группы имеют разную конверсию
#
# подтвердилась - p-value = 0,285

# %% [markdown]
# №2
#
# **Нулевая гипотеза:** Пользователи подгруппы контрольной группы начали пользоваться фичей (практически) одновременно
#
# **Альтернативная:** Пользователи подгруппы контрольной группы начали пользоваться фичей неодновременно
#
# подтвердилась - p-value =

# %% [markdown]
# # Гипотезы A/A treatment

# %% [markdown]
# №1
#
# **Нулевая гипотеза:** Подгруппы тестовой группы имеют одинаковую конверсию
#
# **Альтернативная:** Подгруппы тестовой группы имеют разную конверсию
#
# подтвердилась - p-value = 0,38

# %% [markdown]
# №2
#
# **Нулевая гипотеза:** Пользователи подгруппы тестовой группы начали пользоваться новой фичей  (практически) одновременно
#
# **Альтернативная:** Пользователи подгруппы тестовой группы начали пользоваться новой фичей   неодновременно
#
# подтвердилась - p-value =

# %% [markdown]
# # Гипотезы A/B control/treatment

# %% [markdown]
# №1
#
# **Нулевая гипотеза:** Конверсия в контроле равна конверсии в тесте
#
# **Альтернативная:** Конверсия в контроле не равна конверсии в тесте

# %% [markdown]
# №2
#
# **Нулевая гипотеза:** Стартовые timestamp для control и treatment не отличаются
#
# **Альтернативная:** Стартовые timestamp для control и treatment отличаются

# %% [markdown]
# №3
#
# **Нулевая гипотеза:** Стартовые timestamp для control и treatment не отличаются
#
# **Альтернативная:** Стартовые timestamp для control и treatment отличаются
