# %%
import pandas as pd

tracks = pd.read_csv("kanye_clean-7.csv")
tracks.head
# Out:
# <bound method NDFrame.head of              album_title      artist                labels  \
# 0    The College Dropout  Kanye West  Def Jam, Roc-A-Fella
# 1    The College Dropout  Kanye West  Def Jam, Roc-A-Fella
# 2    The College Dropout  Kanye West  Def Jam, Roc-A-Fella
# 3    The College Dropout  Kanye West  Def Jam, Roc-A-Fella
# 4    The College Dropout  Kanye West  Def Jam, Roc-A-Fella
# ..                   ...         ...                   ...
# 217           VULTURES 2         ¥$                   YZY
# 218           VULTURES 2         ¥$                   YZY
# 219           VULTURES 2         ¥$                   YZY
# 220           VULTURES 2         ¥$                   YZY
# 221           VULTURES 2         ¥$                   YZY
#
#                                                 genres  critic_score  \
# 0    Chipmunk Soul, Pop Rap, Conscious Hip Hop, Neo...            81
# 1    Chipmunk Soul, Pop Rap, Conscious Hip Hop, Neo...            81
# ...
